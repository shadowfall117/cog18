# %% [markdown]
# <font size="5"><strong>Project Description</strong></font>
# <p>This project is a aritifical assitance that will help you to assemble a desktop computer. You can choose the components provided, and put them into users' shopping cart. Users can also calculate the total price of all purchased items in their carts, which can be pretty helpful. However, sometimes the guidelines are not very clear, so please read the README file to make it clear. I will also include an image of an example conversation to let you know what it is like.</p>

# %%
from my_module.chatbot import*
from my_module.test_functions import*

# %%
have_chat()
# Out:
# Hello, I am your artifical assitance, and I can help you to assemble a computer through this chat. There are 7 main components:CPU, GPU, Motherborad, Memory, Cooling, Power, or computer case. Type in any components to begin.
# ---Input---:	cpu
# There are two company that produces CPU, which one will you choose? Type in "intel" or "ryzen"
# ---Input---:	intel
# ['i5-3330', 'i5-4570', 'i5-6500', 'i5-7500', 'i5-8600k', 'i5-9600kf', 'i7-6800k', 'i7-7700k', 'i7-8700k', 'i7-9700k', 'i9-9900', 'i9-9900k']
# You can start shopping or get detailed info of products that you interested in
#
#  Here is a list of commands that you can use:
#  "instructions":print all commands that you can use
#  "cpu","gpu","motherboard","cooling","memory","power","computer case":enter in a section
#  "start shopping":begin to shop
#  "show shopping list":show the item you purchased
#  "finish shopping":type this when you finish shopping(***important***)
#  "info":get detailed info of item such as price or frequencies
#  "total price":return the total price in the list
#  "exit":exit the chat
#
# ---Input---:	info
# You can type the model name to get detailed info.
# ---Input---:	i9-9900k
# {'brand': 'Intel', 'model': 'i9-9900k', 'price': '499', 'data': '5.2GHz'}
# ---Input---:	start shopping
# You can type in the product name you want to purchase, and type in "show shopping list" to show the products you purchased. When you finished, please type in "finish shopping".
# ---Input---:	i9-9900k
# Successfully Stored
# {'brand': 'Intel', 'model': 'i9-9900k', 'price': '499', 'data': '5.2GHz'}
# ---Input---:	gpu
# There is a lists of all graphic cards we provided
# ['gtx1050', 'gtx1050ti', 'gtx1060', 'gtx1060ti', 'gtx1070', 'gtx1070ti', 'gtx1080', 'gtx1080ti', 'rtx2060', 'rtx2070', 'rtx2080', 'rtx2080ti']
#
#  Here is a list of commands that you can use:
#  "instructions":print all commands that you can use
#  "cpu","gpu","motherboard","cooling","memory","power","computer case":enter in a section
#  "start shopping":begin to shop
#  "show shopping list":show the item you purchased
#  "finish shopping":type this when you finish shopping(***important***)
#  "info":get detailed info of item such as price or frequencies
#  "total price":return the total price in the list
#  "exit":exit the chat
#
# ---Input---:	rtx2080ti
# {'brand': 'Nvidia', 'model': 'rtx2080ti', 'price': '1399', 'data': '11GB'}
# Successfully Stored
# ---Input---:	motherboard
# There is a lists of all motherboards we provided
# ['b450', 'b360', 'z390', 'h370']
#
#  Here is a list of commands that you can use:
#  "instructions":print all commands that you can use
#  "cpu","gpu","motherboard","cooling","memory","power","computer case":enter in a section
#  "start shopping":begin to shop
#  "show shopping list":show the item you purchased
#  "finish shopping":type this when you finish shopping(***important***)
#  "info":get detailed info of item such as price or frequencies
#  "total price":return the total price in the list
#  "exit":exit the chat
#
# ---Input---:	h370
# {'brand': 'gigabyte', 'model': 'h370', 'price': '134', 'data': '22.7x14.4x14.8in'}
# Successfully Stored
# ---Input---:	cooling
# There is a lists of all cooling devices we provided. There are two main producers: noctua and cosair, which one would you choose? Please type in "noctua" or "cosair"
# ---Input---:	noctua
# ['nh-u12s', 'nh-u14s', 'nh-d15s']
#
#  Here is a list of commands that you can use:
#  "instructions":print all commands that you can use
#  "cpu","gpu","motherboard","cooling","memory","power","computer case":enter in a section
#  "start shopping":begin to shop
#  "show shopping list":show the item you purchased
#  "finish shopping":type this when you finish shopping(***important***)
#  "info":get detailed info of item such as price or frequencies
#  "total price":return the total price in the list
#  "exit":exit the chat
#
# ---Input---:	nh-d15s
# {'brand': 'noctua', 'model': 'nh-d15s', 'price': '99', 'data': '140mm'}
# Successfully Stored
# ---Input---:	memory
# There is a lists of all memory sticks we provided
# ['ddr4-8gb', 'ddr4-16gb', 'ddr3-4gb', 'ddr3-8gb', 'ddr3-16gb']
#
#  Here is a list of commands that you can use:
#  "instructions":print all commands that you can use
#  "cpu","gpu","motherboard","cooling","memory","power","computer case":enter in a section
#  "start shopping":begin to shop
#  "show shopping list":show the item you purchased
#  "finish shopping":type this when you finish shopping(***important***)
#  "info":get detailed info of item such as price or frequencies
#  "total price":return the total price in the list
#  "exit":exit the chat
#
# ---Input---:	ddr4-16gb
# {'brand': 'Kingston', 'model': 'ddr4-16gb', 'price': '94', 'data': '3200MHz'}
# Successfully Stored
# ---Input---:	power
# There is a lists of all power supply we provided. You can choose between EVGA or Cosair. You need to type "evga" or "cosair"
# ---Input---:	cosair
# ['h115i', 'h60']
#
#  Here is a list of commands that you can use:
#  "instructions":print all commands that you can use
#  "cpu","gpu","motherboard","cooling","memory","power","computer case":enter in a section
#  "start shopping":begin to shop
#  "show shopping list":show the item you purchased
#  "finish shopping":type this when you finish shopping(***important***)
#  "info":get detailed info of item such as price or frequencies
#  "total price":return the total price in the list
#  "exit":exit the chat
#
# ['rm750x', 'rm850x', 'rm1000x', 'rm650x']
#
#  Here is a list of commands that you can use:
#  "instructions":print all commands that you can use
#  "cpu","gpu","motherboard","cooling","memory","power","computer case":enter in a section
#  "start shopping":begin to shop
#  "show shopping list":show the item you purchased
#  "finish shopping":type this when you finish shopping(***important***)
#  "info":get detailed info of item such as price or frequencies
#  "total price":return the total price in the list
#  "exit":exit the chat
#
# ---Input---:	rm1000x
# {'brand': 'cosair', 'model': 'rm1000x', 'price': '176', 'data': '1000Watt'}
# Successfully Stored
# ---Input---:	computer case
# There is a lists of all computer cases we provided. There are four different brand: Fractal Design, Thermaltake, Cooler Master, and Antec. Type in one of them.
# ---Input---:	fractal design
# ['meshify c', 'meshify c-dark', 'meshify c-mini']
#
#  Here is a list of commands that you can use:
#  "instructions":print all commands that you can use
#  "cpu","gpu","motherboard","cooling","memory","power","computer case":enter in a section
#  "start shopping":begin to shop
#  "show shopping list":show the item you purchased
#  "finish shopping":type this when you finish shopping(***important***)
#  "info":get detailed info of item such as price or frequencies
#  "total price":return the total price in the list
#  "exit":exit the chat
#
# ---Input---:	meshify c
# {'brand': 'Fractal Design', 'model': 'meshify c', 'price': '89', 'data': 'Mid-Tower'}
# Successfully Stored
# ---Input---:	show shopping list
# ['i9-9900k', 'rtx2080ti', 'h370', 'nh-d15s', 'ddr4-16gb', 'rm1000x', 'meshify c']
# ---Input---:	total price
# 2490$
# ---Input---:	exit
# See you next time

# %% [markdown]
# <font size="5"><strong>Test</strong></font>

# %%
check_all()
# Out:
# test finished
